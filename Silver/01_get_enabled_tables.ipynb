# %%
import json

query = """
SELECT DISTINCT concat('bronze.',table_name) as source_table
FROM workspace.audit.validation_summary
WHERE brnz_status = 'PASS'
"""

tables = [
    row["source_table"]
    for row in spark.sql(query).collect()
]

print(tables)

# STORE TASK VALUE
dbutils.jobs.taskValues.set(
    key="table_list",
    value=tables
)

dbutils.notebook.exit("SUCCESS")
