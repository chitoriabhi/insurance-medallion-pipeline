# %%
# %sql
drop table configs.migration_config ;
CREATE TABLE configs.migration_config (

    -- =====================================
    -- SOURCE CONNECTION
    -- =====================================

    source_name STRING,
    jdbc_url STRING,
    driver STRING,
    `user` STRING,
    `password` STRING,

    -- =====================================
    -- SOURCE/TARGET TABLES
    -- =====================================

    source_table STRING,
    target_table STRING,

    -- =====================================
    -- LOAD STRATEGY
    -- =====================================

    load_strategy STRING,

    -- =====================================
    -- MANUAL CHUNK SETTINGS
    -- =====================================

    chunk_column STRING,
    chunk_size INT,

    -- =====================================
    -- JDBC PARTITION SETTINGS
    -- =====================================

    partition_column STRING,
    lower_bound String,
    upper_bound String,
    num_partitions INT,

    -- =====================================
    -- GENERAL
    -- =====================================

    enabled BOOLEAN,

    description STRING
);

# %%
# %sql
DELETE FROM configs.migration_config;

INSERT INTO configs.migration_config VALUES

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','customers','bronze.customers','JDBC_PARTITION',NULL,NULL,'customer_id',1,300000,10,true,'Customers table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','addresses','bronze.addresses','JDBC_PARTITION',NULL,NULL,'address_id',1,600000,10,true,'Addresses table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','agents','bronze.agents','JDBC_PARTITION',NULL,NULL,'agent_id',1,20000,5,true,'Agents table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','applications','bronze.applications','JDBC_PARTITION',NULL,NULL,'application_id',1,200000,10,true,'Applications table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','underwriting_assessments','bronze.underwriting_assessments','JDBC_PARTITION',NULL,NULL,'assessment_id',1,200000,10,true,'Underwriting assessments JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','medical_records','bronze.medical_records','JDBC_PARTITION',NULL,NULL,'medical_record_id',1,300000,10,true,'Medical records JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','policies','bronze.policies','JDBC_PARTITION',NULL,NULL,'policy_id',1,200000,10,true,'Policies table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','beneficiaries','bronze.beneficiaries','JDBC_PARTITION',NULL,NULL,'beneficiary_id',1,600000,10,true,'Beneficiaries JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','policy_riders','bronze.policy_riders','JDBC_PARTITION',NULL,NULL,'rider_id',1,200000,10,true,'Policy riders JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','billing_accounts','bronze.billing_accounts','JDBC_PARTITION',NULL,NULL,'billing_account_id',1,200000,10,true,'Billing accounts JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','premium_payments','bronze.premium_payments','JDBC_PARTITION',NULL,NULL,'payment_id',1,800000,10,true,'Premium payments JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','claims','bronze.claims','JDBC_PARTITION',NULL,NULL,'claim_id',1,200000,5,true,'Claims JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','documents','bronze.documents','JDBC_PARTITION',NULL,NULL,'document_id',1,300000,10,true,'Documents JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','audit_log','bronze.audit_log','JDBC_PARTITION',NULL,NULL,'audit_id',1,500000,10,true,'Audit log JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-orange-glade-aqhya4sf-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_gd4S0XIupWVP','policy_dividends','bronze.policy_dividends','JDBC_PARTITION',NULL,NULL,'dividend_id',1,200000,10,true,'Policy dividends JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','customers','bronze.customers','JDBC_PARTITION',NULL,NULL,'customer_id',1,300000,10,true,'Customers table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','addresses','bronze.addresses','JDBC_PARTITION',NULL,NULL,'address_id',1,600000,10,true,'Addresses table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','agents','bronze.agents','JDBC_PARTITION',NULL,NULL,'agent_id',1,20000,5,true,'Agents table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','applications','bronze.applications','JDBC_PARTITION',NULL,NULL,'application_id',1,200000,10,true,'Applications table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','underwriting_assessments','bronze.underwriting_assessments','JDBC_PARTITION',NULL,NULL,'assessment_id',1,200000,10,true,'Underwriting assessments JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','medical_records','bronze.medical_records','JDBC_PARTITION',NULL,NULL,'medical_record_id',1,300000,10,true,'Medical records JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','policies','bronze.policies','JDBC_PARTITION',NULL,NULL,'policy_id',1,200000,10,true,'Policies table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','beneficiaries','bronze.beneficiaries','JDBC_PARTITION',NULL,NULL,'beneficiary_id',1,600000,10,true,'Beneficiaries JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','policy_riders','bronze.policy_riders','JDBC_PARTITION',NULL,NULL,'rider_id',1,200000,10,true,'Policy riders JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','billing_accounts','bronze.billing_accounts','JDBC_PARTITION',NULL,NULL,'billing_account_id',1,200000,10,true,'Billing accounts JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','premium_payments','bronze.premium_payments','JDBC_PARTITION',NULL,NULL,'payment_id',1,800000,10,true,'Premium payments JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','claims','bronze.claims','JDBC_PARTITION',NULL,NULL,'claim_id',1,200000,5,true,'Claims JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','documents','bronze.documents','JDBC_PARTITION',NULL,NULL,'document_id',1,300000,10,true,'Documents JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','audit_log','bronze.audit_log','JDBC_PARTITION',NULL,NULL,'audit_id',1,500000,10,true,'Audit log JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-lively-glade-aq4s8iyu-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_cAVSikFnp8I0','policy_dividends','bronze.policy_dividends','JDBC_PARTITION',NULL,NULL,'dividend_id',1,200000,10,true,'Policy dividends JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','customers','bronze.customers','JDBC_PARTITION',NULL,NULL,'customer_id',1,300000,10,true,'Customers table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','addresses','bronze.addresses','JDBC_PARTITION',NULL,NULL,'address_id',1,600000,10,true,'Addresses table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','agents','bronze.agents','JDBC_PARTITION',NULL,NULL,'agent_id',1,20000,5,true,'Agents table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','applications','bronze.applications','JDBC_PARTITION',NULL,NULL,'application_id',1,200000,10,true,'Applications table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','underwriting_assessments','bronze.underwriting_assessments','JDBC_PARTITION',NULL,NULL,'assessment_id',1,200000,10,true,'Underwriting assessments JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','medical_records','bronze.medical_records','JDBC_PARTITION',NULL,NULL,'medical_record_id',1,300000,10,true,'Medical records JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','policies','bronze.policies','JDBC_PARTITION',NULL,NULL,'policy_id',1,200000,10,true,'Policies table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','beneficiaries','bronze.beneficiaries','JDBC_PARTITION',NULL,NULL,'beneficiary_id',1,600000,10,true,'Beneficiaries JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','policy_riders','bronze.policy_riders','JDBC_PARTITION',NULL,NULL,'rider_id',1,200000,10,true,'Policy riders JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','billing_accounts','bronze.billing_accounts','JDBC_PARTITION',NULL,NULL,'billing_account_id',1,200000,10,true,'Billing accounts JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','premium_payments','bronze.premium_payments','JDBC_PARTITION',NULL,NULL,'payment_id',1,800000,10,true,'Premium payments JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','claims','bronze.claims','JDBC_PARTITION',NULL,NULL,'claim_id',1,200000,5,true,'Claims JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','documents','bronze.documents','JDBC_PARTITION',NULL,NULL,'document_id',1,300000,10,true,'Documents JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','audit_log','bronze.audit_log','JDBC_PARTITION',NULL,NULL,'audit_id',1,500000,10,true,'Audit log JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-fragrant-rain-aq2fxjvp-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require','org.postgresql.Driver','neondb_owner','npg_GR2YnkaNev4c','policy_dividends','bronze.policy_dividends','JDBC_PARTITION',NULL,NULL,'dividend_id',1,200000,10,true,'Policy dividends JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','customers','bronze.customers','JDBC_PARTITION',NULL,NULL,'customer_id',1,300000,10,true,'Customers table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','addresses','bronze.addresses','JDBC_PARTITION',NULL,NULL,'address_id',1,600000,10,true,'Addresses table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','agents','bronze.agents','JDBC_PARTITION',NULL,NULL,'agent_id',1,20000,5,true,'Agents table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','applications','bronze.applications','JDBC_PARTITION',NULL,NULL,'application_id',1,200000,10,true,'Applications table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','underwriting_assessments','bronze.underwriting_assessments','JDBC_PARTITION',NULL,NULL,'assessment_id',1,200000,10,true,'Underwriting assessments JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','medical_records','bronze.medical_records','JDBC_PARTITION',NULL,NULL,'medical_record_id',1,300000,10,true,'Medical records JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','policies','bronze.policies','JDBC_PARTITION',NULL,NULL,'policy_id',1,200000,10,true,'Policies table JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','beneficiaries','bronze.beneficiaries','JDBC_PARTITION',NULL,NULL,'beneficiary_id',1,600000,10,true,'Beneficiaries JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','policy_riders','bronze.policy_riders','JDBC_PARTITION',NULL,NULL,'rider_id',1,200000,10,true,'Policy riders JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','billing_accounts','bronze.billing_accounts','JDBC_PARTITION',NULL,NULL,'billing_account_id',1,200000,10,true,'Billing accounts JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','premium_payments','bronze.premium_payments','JDBC_PARTITION',NULL,NULL,'payment_id',1,800000,10,true,'Premium payments JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','claims','bronze.claims','JDBC_PARTITION',NULL,NULL,'claim_id',1,200000,5,true,'Claims JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','documents','bronze.documents','JDBC_PARTITION',NULL,NULL,'document_id',1,300000,10,true,'Documents JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','audit_log','bronze.audit_log','JDBC_PARTITION',NULL,NULL,'audit_id',1,500000,10,true,'Audit log JDBC partition load'),

('neon_prod','jdbc:postgresql://ep-bitter-dew-aqwifctp.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require','org.postgresql.Driver','neondb_owner','npg_3zuRcP1LMtmZ','policy_dividends','bronze.policy_dividends','JDBC_PARTITION',NULL,NULL,'dividend_id',1,200000,10,true,'Policy dividends JDBC partition load');

# %%
# %sql
DELETE FROM configs.migration_config;
CREATE CATALOG IF NOT EXISTS bronze;

INSERT INTO configs.migration_config VALUES
('postgres_policy_admin_db',
'jdbc:postgresql://61.12.91.141:54322/policy_admin_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.addresses',
'bronze.policy_admin_db.addresses',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'addresses table load'),

('postgres_policy_admin_db',
'jdbc:postgresql://61.12.91.141:54322/policy_admin_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.agents',
'bronze.policy_admin_db.agents',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'agents table load'),

('postgres_policy_admin_db',
'jdbc:postgresql://61.12.91.141:54322/policy_admin_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.applications',
'bronze.policy_admin_db.applications',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'applications table load'),

('postgres_policy_admin_db',
'jdbc:postgresql://61.12.91.141:54322/policy_admin_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.beneficiaries',
'bronze.policy_admin_db.beneficiaries',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'beneficiaries table load'),

('postgres_policy_admin_db',
'jdbc:postgresql://61.12.91.141:54322/policy_admin_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.customers',
'bronze.policy_admin_db.customers',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'customers table load'),

('postgres_policy_admin_db',
'jdbc:postgresql://61.12.91.141:54322/policy_admin_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.medical_records',
'bronze.policy_admin_db.medical_records',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'medical_records table load'),

('postgres_policy_admin_db',
'jdbc:postgresql://61.12.91.141:54322/policy_admin_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.policies',
'bronze.policy_admin_db.policies',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'policies table load'),

('postgres_policy_admin_db',
'jdbc:postgresql://61.12.91.141:54322/policy_admin_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.policy_riders',
'bronze.policy_admin_db.policy_riders',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'policy_riders table load'),

('postgres_policy_admin_db',
'jdbc:postgresql://61.12.91.141:54322/policy_admin_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.policy_status_history',
'bronze.policy_admin_db.policy_status_history',
'JDBC_PARTITION',
NULL,NULL,
'history_id','1','10000000',10,
true,
'policy_status_history table load'),

('postgres_policy_admin_db',
'jdbc:postgresql://61.12.91.141:54322/policy_admin_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.providers',
'bronze.policy_admin_db.providers',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'providers table load');


INSERT INTO configs.migration_config VALUES
('postgres_ops_compliance_db',
'jdbc:postgresql://61.12.91.141:54322/ops_compliance_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.audit_log',
'bronze.ops_compliance_db.audit_log',
'JDBC_PARTITION',
NULL,NULL,
'audit_id','1','10000000',10,
true,
'audit_log table load'),

('postgres_ops_compliance_db',
'jdbc:postgresql://61.12.91.141:54322/ops_compliance_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.billing_accounts',
'bronze.ops_compliance_db.billing_accounts',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'billing_accounts table load'),

('postgres_ops_compliance_db',
'jdbc:postgresql://61.12.91.141:54322/ops_compliance_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.claims',
'bronze.ops_compliance_db.claims',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'claims table load'),

('postgres_ops_compliance_db',
'jdbc:postgresql://61.12.91.141:54322/ops_compliance_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.compliance_events',
'bronze.ops_compliance_db.compliance_events',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'compliance_events table load'),

('postgres_ops_compliance_db',
'jdbc:postgresql://61.12.91.141:54322/ops_compliance_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.documents',
'bronze.ops_compliance_db.documents',
'JDBC_PARTITION',
NULL,NULL,
'uploaded_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'documents table load'),

('postgres_ops_compliance_db',
'jdbc:postgresql://61.12.91.141:54322/ops_compliance_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.policy_dividends',
'bronze.ops_compliance_db.policy_dividends',
'JDBC_PARTITION',
NULL,NULL,
'dividend_id','1','10000000',10,
true,
'policy_dividends table load'),

('postgres_ops_compliance_db',
'jdbc:postgresql://61.12.91.141:54322/ops_compliance_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.premium_payments',
'bronze.ops_compliance_db.premium_payments',
'JDBC_PARTITION',
NULL,NULL,
'created_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'premium_payments table load'),

('postgres_ops_compliance_db',
'jdbc:postgresql://61.12.91.141:54322/ops_compliance_db',
'org.postgresql.Driver',
'databricks_pennm_user',
'ez#5FOr3eFUhG%ps',
'public.underwriting_assessments',
'bronze.ops_compliance_db.underwriting_assessments',
'JDBC_PARTITION',
NULL,NULL,
'assessed_at', '2020-01-01 00:00:00', '2026-12-31 23:59:59',10,
true,
'underwriting_assessments table load');

# %%
# %sql
SELECT * from configs.migration_config

# %%
catalog_name = "bronze"
schema_name = "policy_admin_db"

tables = spark.sql(f"SHOW TABLES IN {catalog_name}.{schema_name}")

for row in tables.collect():
    table_name = row.tableName
    spark.sql(
        f"DROP TABLE IF EXISTS {catalog_name}.{schema_name}.{table_name}"
    )
    print(f"Dropped: {catalog_name}.{schema_name}.{table_name}")

# %%
catalog_name = "bronze"
schema_name = "policy_admin_db"

tables = spark.sql(f"SHOW TABLES IN {catalog_name}.{schema_name}")

for row in tables.collect():
    table_name = row.tableName
    spark.sql(
        f"DROP TABLE IF EXISTS {catalog_name}.{schema_name}.{table_name}"
    )
    print(f"Dropped: {catalog_name}.{schema_name}.{table_name}")

# %%
spark.sql(
        f"DROP TABLE IF EXISTS workspace.audit.validation_summary"
    )

# %%
# %sql
Select 'addresses' as tble_name,Count(*)  From workspace.bronze.addresses UNION ALL
Select 'agents' as tble_name,Count(*)  From workspace.bronze.agents UNION ALL
Select 'applications' as tble_name,Count(*)  From workspace.bronze.applications UNION ALL
Select 'audit_log' as tble_name,Count(*) From  workspace.bronze.audit_log UNION ALL
Select 'beneficiaries' as tble_name,Count(*) From  workspace.bronze.beneficiaries UNION ALL
Select 'billing_accounts' as tble_name,Count(*) From  workspace.bronze.billing_accounts UNION ALL
Select 'claims' as tble_name,Count(*) From  workspace.bronze.claims UNION ALL
Select 'customers' as tble_name,Count(*) From  workspace.bronze.customers UNION ALL
Select 'documents' as tble_name,Count(*) From  workspace.bronze.documents UNION ALL
Select 'medical_records' as tble_name,Count(*) From  workspace.bronze.medical_records UNION ALL
Select 'policies' as tble_name,Count(*) From  workspace.bronze.policies UNION ALL
Select 'policy_dividends' as tble_name,Count(*) From  workspace.bronze.policy_dividends UNION ALL
Select 'policy_riders' as tble_name,Count(*) From  workspace.bronze.policy_riders UNION ALL
Select 'premium_payments' as tble_name,Count(*) From  workspace.bronze.premium_payments UNION ALL
Select 'underwriting_assessments' as tble_name,Count(*) From  workspace.bronze.underwriting_assessments;

# %%
# %sql
Select count(*) from configs.migration_config limit 10
