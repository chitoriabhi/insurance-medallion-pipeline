# %%
dbutils.widgets.text("gold_table_name", "")

gold_table_name = dbutils.widgets.get("gold_table_name")

print("RAW INPUT:")
print(gold_table_name)

if gold_table_name == "dim_customer":

    dbutils.notebook.run(
        "/Workspace/Users/chittoriarocks@gmail.com/Gold_files/dimensions/dim_customer", 
        0
    )


elif gold_table_name == "fact_claim":

    dbutils.notebook.run(
        "/Workspace/Users/chittoriarocks@gmail.com/Gold_files/facts/fact_claim",
        0
    )
